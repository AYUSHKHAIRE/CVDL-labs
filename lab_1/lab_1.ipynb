# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# https://www.image-map.net/
# go upload and click . crop from top left to bottom right .

# %%
img = cv2.imread('../images/KOA_Nassau_2697x1517.jpg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)
plt.show()

# %%
img_rgb.shape
# Out:
# (1080, 1920, 3)

# %%
type(img_rgb)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Modify the position of a dog in an image by manipulating its coordinates using NumPy.

# %%
dog_bbox = (693, 142, 521, 828)  # x, y, width, height
x, y, w, h = dog_bbox
dog_region = img[y:y+h, x:x+w]
actual_height, actual_width, _ = dog_region.shape
# print(f"Cropped Dog Dimensions: Height={actual_height}, Width={actual_width}")
modified_img = np.copy(img)
modified_img[y:y+h, x:x+w] = 0  
new_x = x + 600  
new_y = y  
if new_x + w > img.shape[1] or new_y + h > img.shape[0]:
    raise ValueError("New position is out of bounds.")
modified_img[new_y:new_y+h, new_x:new_x+w] = dog_region
cv2.imwrite("modified_dog_img.jpg", modified_img)
# Out:
# True
